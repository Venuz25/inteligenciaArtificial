# %% [markdown]
# # **Práctica 8: Máquinas de soporte vectorial**

# %% [markdown]
# **Integrantes:**
#
#
# *   Aguirre Lanto Victor Manuel
# *   Gasca Fragoso Pedro
# *   Guevara Badillo Areli Alejandra
# *   Montiel Toro Arael de Jesús
# *   Ramírez Lozano Gael Martin

# %% [markdown]
# ## Dataset make_blobs

# %%
import numpy as np
from sklearn.datasets import make_blobs

# Generación del dataset: 100 muestras, 3 centros (clases), 2 características
X_blobs, y_blobs = make_blobs(n_samples=100, centers=3, n_features=2, random_state=42)
blobs_dataset = {'data': X_blobs, 'target': y_blobs, 'feature_names': ['feature_1', 'feature_2']}

print("==================================================")
print("Dataset: make_blobs")
print("==================================================")

# 1. Imprimir cada conjunto de datos de entrada.
print("\n1. Impresión de los datos principales (Primeras 5 filas):")
print(f"Características (X):\n{blobs_dataset['data'][:5]}")
print(f"Etiquetas (y):\n{blobs_dataset['target'][:5]}")

# 2. Imprimir la información de cada conjunto de datos de entrada usando dataset.keys().
print(f"\n2. Claves del dataset (dataset.keys()):")
print(blobs_dataset.keys())

# 3. Imprimir las características y mostrar el número de datos y el número de características/atributos.
n_samples = blobs_dataset['data'].shape[0]
n_features = blobs_dataset['data'].shape[1]

print(f"\n3. Información de forma y características:")
print(f"Número total de datos (muestras): {n_samples}")
print(f"Número de características/atributos: {n_features}")
print(f"Nombres de las características: {blobs_dataset['feature_names']}")
# Out:
# ...
# Dataset: make_blobs
# ...
#
# 1. Impresión de los datos principales (Primeras 5 filas):
# Características (X):
# [[-7.72642091 -8.39495682]
#  [ 5.45339605  0.74230537]
#  [-2.97867201  9.55684617]
#  [ 6.04267315  0.57131862]
#  [-6.52183983 -6.31932507]]
# Etiquetas (y):
# [2 1 0 1 2]
#
# 2. Claves del dataset (dataset.keys()):
# dict_keys(['data', 'target', 'feature_names'])
#
# 3. Información de forma y características:
# Número total de datos (muestras): 100
# Número de características/atributos: 2
# Nombres de las características: ['feature_1', 'feature_2']

# %% [markdown]
# ## Dataset make_circles

# %%
import numpy as np
from sklearn.datasets import make_circles

# Generación del dataset: 100 muestras, 2 clases (círculo interior y exterior), 2 características
X_circles, y_circles = make_circles(n_samples=100, factor=.7, noise=.05, random_state=42)
circles_dataset = {'data': X_circles, 'target': y_circles, 'feature_names': ['feature_1', 'feature_2']}

print("==================================================")
print("Dataset: make_circles")
print("==================================================")

# 1. Imprimir cada conjunto de datos de entrada.
print("\n1. Impresión de los datos principales (Primeras 5 filas):")
print(f"Características (X):\n{circles_dataset['data'][:5]}")
print(f"Etiquetas (y):\n{circles_dataset['target'][:5]}")

# 2. Imprimir la información de cada conjunto de datos de entrada usando dataset.keys().
print(f"\n2. Claves del dataset (dataset.keys()):")
print(circles_dataset.keys())

# 3. Imprimir las características y mostrar el número de datos y el número de características/atributos.
n_samples = circles_dataset['data'].shape[0]
n_features = circles_dataset['data'].shape[1]

print(f"\n3. Información de forma y características:")
print(f"Número total de datos (muestras): {n_samples}")
print(f"Número de características/atributos: {n_features}")
print(f"Nombres de las características: {circles_dataset['feature_names']}")
# Out:
# ...
# Dataset: make_circles
# ...
#
# 1. Impresión de los datos principales (Primeras 5 filas):
# Características (X):
# [[-0.3432635  -0.63636558]
#  [ 0.67464567  0.32287025]
#  [-0.55573255  0.44130191]
#  [ 0.76420024 -0.59338464]
#  [ 0.80241569 -0.74074202]]
# Etiquetas (y):
# [1 1 1 0 0]
#
# 2. Claves del dataset (dataset.keys()):
# dict_keys(['data', 'target', 'feature_names'])
#
# 3. Información de forma y características:
# Número total de datos (muestras): 100
# Número de características/atributos: 2
# Nombres de las características: ['feature_1', 'feature_2']

# %% [markdown]
# ## Dataset load_digits

# %%
from sklearn.datasets import load_digits

# Carga del dataset
digits_dataset = load_digits()

print("==================================================")
print("Dataset: load_digits")
print("==================================================")

# 1. Imprimir cada conjunto de datos de entrada.
print("\n1. Impresión de la estructura completa del dataset (Bunch/Diccionario):")
# NOTA: La clave 'data' contiene la matriz de características. La clave 'DESCR' es la descripción del dataset.
print(digits_dataset)

# 2. Imprimir la información de cada conjunto de datos de entrada usando dataset.keys().
print(f"\n2. Claves del dataset (dataset.keys()):")
print(digits_dataset.keys())

# 3. Imprimir las características y mostrar el número de datos y el número de características/atributos.
n_samples = digits_dataset['data'].shape[0]
n_features = digits_dataset['data'].shape[1]

print(f"\n3. Información de forma y características:")
print(f"Número total de datos (muestras): {n_samples}")
# El número de características es 64 porque cada imagen de 8x8 se ha aplanado (8*8=64 píxeles).
print(f"Número de características/atributos: {n_features}")
print(f"Nombres de las características: {digits_dataset['feature_names']}")
# Out:
# ...
# Dataset: load_digits
# ...
#
# 1. Impresión de la estructura completa del dataset (Bunch/Diccionario):
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
# ...

# %% [markdown]
# ## Problemas de clases linealmente separables

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
import matplotlib

# Generamos 80 muestras con dos características, asociadas a dos clases
X, y = make_blobs(n_samples=80, n_features=2, centers=2, random_state=21, center_box=(0, 10.0))

# Creamos el modelo SVM para clasificación con kernel Lineal y entrenamos el modelo
clf = svm.SVC(kernel='linear', C=100)
clf.fit(X, y)

# Graficamos los datos en el espacio de características
cmap = matplotlib.colors.ListedColormap(['b', 'r'])
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=cmap)

# Creamos un mesh para evaluar la función de decisión
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# Graficamos el hiperplano y el margen
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Graficamos los vectores soporte
#ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')

Z_pred = clf.predict(np.c_[XX.ravel(), YY.ravel()])
Z_pred = Z_pred.reshape(XX.shape)

cmap = matplotlib.colors.ListedColormap(['c', 'm'])
plt.pcolormesh(XX, YY, Z_pred, cmap=cmap, alpha=0.1)

new_x = [[5, 0.5]]
new_z = clf.predict(new_x)
if new_z[0] == 0: color = 'b'
else: color = 'r'

plt.scatter(new_x[0][0], new_x[0][1], marker='+', color=color, s=300)
plt.grid()
plt.show()

# %% [markdown]
# ## Problema de clases linealmente no separables usando el truco de Kernel

# %%
from sklearn.datasets import make_circles

# Veamos el uso de kernels para el problema de clases linealmente no separables
# generamos 50 muestras con dos características, asociadas a dos clases
X, y = make_circles(50, factor=.2, noise=.2)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

# Creamos el modelo SVM para clasificación con kernel Lineal/rbf y entrenamos el modelo
clf = svm.SVC(kernel='linear', C=100).fit(X, y)

# Graficamos los datos en el espacio de características
cmap = matplotlib.colors.ListedColormap(['b', 'r'])
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=cmap)

# Creamos un mesh para evaluar la función de decisión
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# Graficamos el hiperplano y el margen
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Graficamos los vectores soporte
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')

Z_pred = clf.predict(np.c_[XX.ravel(), YY.ravel()])
Z_pred = Z_pred.reshape(XX.shape)

cmap = matplotlib.colors.ListedColormap(['purple', 'lime'])
plt.pcolormesh(XX, YY, Z_pred, cmap=cmap, alpha=0.1)

plt.grid()
plt.show()

# %% [markdown]
# ### Truco Kernel

# %%
# Veamos el efecto del truco kernel (aumentando la dimensionalidad del espacio de entradas)
from mpl_toolkits import mplot3d

# Aplicamos una operación de kernel gaussiano para separar las clases
# Gamma controla el efecto del kernel, si es muy pequeño el modelo se parece al lineal
gamma = 1
Xr = np.exp(-gamma*(X ** 2).sum(1))

# Graficamos el espacio de características mapeado por el kernel
ax = plt.subplot(projection='3d')
cmap = matplotlib.colors.ListedColormap( [ 'b', 'r' ] )
ax.scatter3D(X[:, 0], X[:, 1], Xr, c=y, s=50, cmap=cmap)

# %% [markdown]
# ## Dataset digits

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd
from sklearn.datasets import load_digits

# cargamos el dataset
digits = load_digits()
print(digits.data.shape)
# Out:
# (1797, 64)

# %%
# Mostramos los digitos en imágenes
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')
    ax.text(0, 7, str(digits.target[i]))

plt.show()

# %%
# Dividimos los datos en entrenamiento y prueba
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(digits.data, digits.target, random_state=0)

# %%
# Definimos la configuración del clasificador
from sklearn import datasets, svm, metrics
clf = svm.SVC(kernel='rbf')

# Entrenamos el clasificador con los datos de entrenamiento
clf.fit(Xtrain, ytrain)
# Out:
# SVC()

# %% [markdown]
# ### Predicción

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt # Importación necesaria para tight_layout

score = clf.score(Xtest, ytest)
print(score)

ypred = clf.predict(Xtest)
matriz = confusion_matrix(ytest, ypred)

plot_confusion_matrix(conf_mat=matriz, figsize=(6,6), show_normed=False)
plt.tight_layout()
plt.show()
# Out:
# 0.9911111111111112
